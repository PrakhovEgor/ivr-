# %%
import pandas as pd

# %%
data = pd.read_csv("classification.csv", sep="", on_bad_lines='skip', encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data = pd.read_csv("classification.csv", sep="", on_bad_lines='skip', encoding='latin-1')
#
# File ~\AppData\Local\Programs\Python\Ivr-garden\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data
# Out:
#                                                    taxonID\tscientificNameID\tlocalID\tscientificName\ttaxonRank\tparentNameUsageID\tscientificNameAuthorship\tfamily\tsubfamily\ttribe\tsubtribe\tgenus\tsubgenus\tspecificEpithet\tinfraspecificEpithet\tverbatimTaxonRank\tnomenclaturalStatus\tnamePublishedIn\ttaxonomicStatus\tacceptedNameUsageID\toriginalNameUsageID\tnameAccordingToID\ttaxonRemarks\tcreated\tmodified\treferences\tsource\tmajorGroup\ttplID
# wfo-0001302010\t\t9905237\t"Schoenoxiphium eckl...                              Kew."\tA\ttro-9905237
# wfo-0001302011\t\t9905253\t"Cyperus violifolia"...                              Kew."\tA\ttro-9905253
# wfo-0001302012\t\t9905297\t"Carex viridula var....                              Kew."\tA\ttro-9905297
# wfo-0001302015\t\t9905399\t"Fimbristylis schulz...                              Kew."\tA\ttro-9905399
# wfo-0001302017\t\t9905458\t"Trichophorum bracte...                              Kew."\tA\ttro-9905458
# ...
